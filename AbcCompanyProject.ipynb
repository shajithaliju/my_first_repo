# %%
import pandas as pd  
import numpy as np  
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("E:\Python Class\Python Project\Copy of myexcel - myexcel.csv.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# changing the data of Height column with any random numbers between 150 and 180.

# %%
# Generate random heights between 150 and 180
heights = np.random.randint(150, 180, len(df))

# Update the 'Height' column with the generated heights
df['Height'] = heights
 
# Print the updated dataframe
print(df)
# Out:
#               Name            Team  Number Position  Age  Height  Weight
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180  \
# 1      Jae Crowder  Boston Celtics      99       SF   25     150     235
# 2     John Holland  Boston Celtics      30       SG   27     175     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     161     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     168     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     154     203
# 454      Raul Neto       Utah Jazz      25       PG   24     154     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     171     256
# 456    Jeff Withey       Utah Jazz      24        C   26     179     231
# 457       Priyanka       Utah Jazz      34        C   25     173     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB

# %% [markdown]
# 1.	How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
df['Team'].value_counts()
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# New York Knicks           16
# Milwaukee Bucks           16
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# Atlanta Hawks             15
# San Antonio Spurs         15
# Houston Rockets           15
# Boston Celtics            15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Sacramento Kings          15
# Phoenix Suns              15
# Los Angeles Lakers        15
# Los Angeles Clippers      15
# Golden State Warriors     15
# Toronto Raptors           15
# Philadelphia 76ers        15
# Dallas Mavericks          15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64

# %%
team_counts = df['Team'].value_counts()
total_count = team_counts.sum()

# Calculate the percentage splits
team_percentage = team_counts / total_count * 100

# Display the unique values and their percentage splits
for team, percentage in zip(team_counts.index, team_percentage):
    print(f'Team: {team}, Percentage: {percentage:.2f}%')
# Out:
# Team: New Orleans Pelicans, Percentage: 4.15%
# Team: Memphis Grizzlies, Percentage: 3.93%
# Team: Utah Jazz, Percentage: 3.49%
# Team: New York Knicks, Percentage: 3.49%
# Team: Milwaukee Bucks, Percentage: 3.49%
# Team: Brooklyn Nets, Percentage: 3.28%
# Team: Portland Trail Blazers, Percentage: 3.28%
# Team: Oklahoma City Thunder, Percentage: 3.28%
# Team: Denver Nuggets, Percentage: 3.28%
# Team: Washington Wizards, Percentage: 3.28%
# Team: Miami Heat, Percentage: 3.28%
# Team: Charlotte Hornets, Percentage: 3.28%
# Team: Atlanta Hawks, Percentage: 3.28%
# Team: San Antonio Spurs, Percentage: 3.28%
# Team: Houston Rockets, Percentage: 3.28%
# Team: Boston Celtics, Percentage: 3.28%
# Team: Indiana Pacers, Percentage: 3.28%
# Team: Detroit Pistons, Percentage: 3.28%
# Team: Cleveland Cavaliers, Percentage: 3.28%
# Team: Chicago Bulls, Percentage: 3.28%
# Team: Sacramento Kings, Percentage: 3.28%
# Team: Phoenix Suns, Percentage: 3.28%
# ...

# %% [markdown]
# 2.	Segregate the employees w.r.t different positions

# %%
grouped_data = df.groupby('Position')

# Iterate over the groups and display the employees in each position
for position, employees in grouped_data:
    print(f"Position: {position}")
    print(employees)
    print()
# Out:
# Position: C
#                 Name                    Team  Number Position  Age  Height
# 7       Kelly Olynyk          Boston Celtics      41        C   25     169  \
# 10   Jared Sullinger          Boston Celtics       7        C   24     168
# 14      Tyler Zeller          Boston Celtics      44        C   26     156
# 23       Brook Lopez           Brooklyn Nets      11        C   28     162
# 27        Henry Sims           Brooklyn Nets      14        C   26     173
# ..               ...                     ...     ...      ...  ...     ...
# 439    Mason Plumlee  Portland Trail Blazers      24        C   26     158
# 447      Rudy Gobert               Utah Jazz      27        C   23     165
# 455     Tibor Pleiss               Utah Jazz      21        C   26     171
# 456      Jeff Withey               Utah Jazz      24        C   26     179
# 457         Priyanka               Utah Jazz      34        C   25     173
#
#      Weight         College      Salary
# ...

# %% [markdown]
# 3.	Find from which age group most of the employees belong to.

# %%
age_counts = df['Age'].value_counts()

# Get the age group with the highest count
most_common_age = age_counts.idxmax()

# Display the age group with the highest count
print(f"The most common age group among employees is: {most_common_age}")
# Out:
# The most common age group among employees is: 24

# %% [markdown]
# 4.	Find out under which team and position, spending in terms of salary is high.

# %%
grouped_data = df.groupby(['Team', 'Position'])['Salary'].sum()

# Find the team and position with the highest total salary
highest_spending = grouped_data.idxmax()
team, position = highest_spending

# Display the team and position with the highest total salary
print(f"The highest spending in terms of salary is under Team: {team}, Position: {position}")
# Out:
# The highest spending in terms of salary is under Team: Los Angeles Lakers, Position: SF

# %% [markdown]
# 5.	Find if there is any correlation between age and salary , represent it visually.

# %%
age_salary_corr = df['Age'].corr(df['Salary'])

# Create a scatter plot to visualize the relationship
plt.scatter(df['Age'], df['Salary'])
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Correlation between Age and Salary')
plt.show()

# Display the correlation coefficient
print(f"The correlation between Age and Salary is: {age_salary_corr}")
# Out:
# The correlation between Age and Salary is: 0.2140094122657097
